# %%
txt = "dfdslmfkjsdlmkf <link=sdfsdf> dfgdfgdfg.\ndskfmsdkfmksdfk<dfgdfg> <dsflmksmfk> <ref=dsfsd/dsfsdf> dsfsdfsdf <dfgdfg>"
import re
pattern = r'<(?!ref=).*?>'
print(re.findall(pattern, txt))
# Out:
# ['<link=sdfsdf>', '<dfgdfg>', '<dsflmksmfk>', '<dfgdfg>']

# %%
from __future__ import annotations
import re
from typing import Iterator, NamedTuple, Union

class ReplacementStr(NamedTuple):
    """
    A namedtuple that represents a replacement rule.

    Args:
        str2replace: The string to be replaced.
        replacement: The replacement string.
    """
    str2replace:str
    replacement:str


class AdvancedStr(str):
    """
    An advanced string that can be used to find and replace advanced HTML tags.

    Attributes:
        __AdvancedBalisesPattern: A dictionary that maps the name of an advanced tag
            to its regular expression pattern.
    """
    __AdvancedBalisesPattern = {
        "reference": "ref=",
        "link": "link="
    }
    # --------------------------- CONSTRUCTOR -------------------------- #
    def __new__(cls, arg):
        """
        Creates a new `AdvancedStr` object.

        Args:
            arg: The string to be wrapped by the `AdvancedStr` object.
        """
        instance = super(AdvancedStr, cls).__new__(cls, arg)
        return instance
    
    # --------------------------- PROPERTIES --------------------------- #
    @property
    def __definitionPattern(self) -> str:
        """
        Generate the regular expression pattern for definitions.

        Returns:
            str: The regular expression pattern.
        """
        if self.__AdvancedBalisesPattern.values():
            excludedPatterns = (
                r"(?!" +
                r'|'.join(list(self.__AdvancedBalisesPattern.values())) +
                ")")
        else:
            excludedPatterns = ""

        return fr'<{excludedPatterns}.*?>'

    def __referencePattern(self) -> str:
        """
        Generate the regular expression pattern for reference tags.

        Returns:
            str: The regular expression pattern.
        """
        return self.__getAdvancedBalisesPattern(
            baliseName= "reference"
            )
    
    def __linkPattern(self) -> str:
        """
        Generate the regular expression pattern for link tags.

        Returns:
            str: The regular expression pattern.
        """
        return self.__getAdvancedBalisesPattern(
            baliseName="link"
            )

    @property
    def definitions(self)-> Iterator[re.Match[str]]:
        """
        Gets an iterator that iterates over all definition tags in the string.

        Yields:
            The next definition tag.
        """
        return self.__getMatches(
            referenceStr=self,
            pattern=self.__definitionPattern)
    
    @property
    def references(self)-> Iterator[re.Match[str]]:
        """
        Gets an iterator that iterates over all reference tags in the string.

        Yields:
            The next reference tag.
        """
        return self.__AdvancedBalises(
            baliseName="reference"
        )
    
    @property
    def links(self)-> Iterator[re.Match[str]]:
        """
        Gets an iterator that iterates over all link tags in the string.

        Yields:
            The next link tag.
        """
        return self.__AdvancedBalises(
            baliseName="link"
        )

    # -------------------------- GENERIC TOOLS ------------------------- #
    
    @staticmethod
    def __getMatches(
            referenceStr : str,
            pattern : str,
            ) -> Iterator[re.Match[str]]:
        """
        Find all matches of a pattern in the reference string.

        Args:
            referenceStr (str): The string to search for matches.
            pattern (str): The regular expression pattern to match.

        Returns:
            Iterator[re.Match[str]]: An iterator of match objects.
        """
        
        return re.finditer(
                pattern,
                referenceStr,
                re.DOTALL)
   
    @staticmethod
    def __listValues(
            balises : Iterator[re.Match[str]],
            ) -> list[str]:
        """
        Extract values from an iterator of match objects.

        Args:
            balises (Iterator[re.Match[str]]): An iterator of match objects.

        Returns:
            list[str]: A list of extracted values.
        """
        return [balise.group()[1:-1] for balise in balises]
    
    def __getAdvancedBalisesPattern(
            self,
            baliseName: str,
        )-> str:
        """
        Generate the regular expression pattern for a specific advanced tag.

        Args:
            baliseName (str): The name of the advanced tag.

        Returns:
            str: The regular expression pattern for the specified advanced tag.
        """
        balisePattern = self.__AdvancedBalisesPattern[baliseName]
        return fr'<{balisePattern}.*?>'
    
    def __AdvancedBalises(
            self,
            baliseName:str,
            )-> Iterator[re.Match[str]]:
        """
        Get an iterator that iterates over all occurrences of a specific advanced tag.

        Args:
            baliseName (str): The name of the advanced tag to search for.

        Yields:
            re.Match[str]: A match object representing an occurrence of the advanced tag.
        """
        return self.__getMatches(
            pattern=self.__getAdvancedBalisesPattern(baliseName=baliseName),
            referenceStr=self)
   
    @staticmethod
    def __replaceElements(
            initial_str : str,
            replacement : ReplacementStr
            ) -> AdvancedStr:
        """
        Replace a specific tag with its corresponding replacement in the string.

        Args:
            initial_str (str): The initial string with the tag to be replaced.
            replacement (ReplacementStr): A ReplacementStr object containing the tag to replace
                and its corresponding replacement.

        Returns:
            AdvancedStr: A new instance of AdvancedStr with the tag replaced.
        """
        
        new_txt = re.sub(
            fr"<{replacement.str2replace}>",
            replacement.replacement,
            initial_str,
            re.DOTALL
            )
        return AdvancedStr(new_txt)

    @staticmethod
    def __replaceListElements(
            original_str: str,
            replacements : list[ReplacementStr]
            ) -> AdvancedStr:
        """
        Replace multiple tags with their corresponding replacements in the string.

        Args:
            original_str (str): The original string with tags to be replaced.
            replacements (list[ReplacementStr]): A list of ReplacementStr objects
                containing the tags to replace and their corresponding replacements.

        Returns:
            AdvancedStr: A new instance of AdvancedStr with replaced tags.
        """
        
        new_str = original_str

        # loop over all definition to replace
        for replacement in replacements:
            new_str = AdvancedStr.__replaceElements(
                initial_str=new_str,
                replacement=replacement
            )
        
        return AdvancedStr(new_str)


    # --------------------------- DEFINITION --------------------------- #
    def getDefinitions(self)-> list[str]:
        """
        Get a list of definition values extracted from the string.

        Returns:
            list[str]: A list of definition values.
        """
        return self.__listValues(self.definitions)
    
    def replaceDefinitions(
            self,
            definitionTag2replace: list[ReplacementStr],
            ) -> AdvancedStr:
        """
        Replace definition tags with provided replacements.

        Args:
            definitionTag2replace (list[ReplacementStr]): A list of ReplacementStr objects
                containing the tags to replace and their corresponding replacements.

        Returns:
            AdvancedStr: A new instance of AdvancedStr with replaced tags.
        """
        
        return self.__replaceListElements(
            original_str=self,
            replacements=definitionTag2replace
        )
      
    # --------------------------- REFERENCES --------------------------- #

    def getReferences(self) -> list[str]:
        """
        Get a list of reference values extracted from the string.

        Returns:
            list[str]: A list of reference values.
        """
        return self.__listValues(self.references)
    
    # ------------------------------ LINKS ----------------------------- #
    def getLinks(self) -> list[str]:
        """
        Get a list of link values extracted from the string.

        Returns:
            list[str]: A list of link values.
        """
        return self.__listValues(self.references)


a =AdvancedStr(txt)

print(a.getDefinitions())

print(a)

b = a.replaceDefinitions([
    ReplacementStr(
    str2replace='dfgdfg',
    replacement="ALLEZ LE SCO"),
    ReplacementStr(
    str2replace='dsflmksmfk',
    replacement="ALLEZ LE PSG")
    ]
)

print(b)
# Out:
#   File <tokenize>:77
#     return self.__getAdvancedBalisesPattern(
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
from pathlib import Path
import shutil
from reqpy import Requirement
from reqpy.requirement import RequirementsSet

mySRS = Path("work/SRS/requirements")
myReport = Path("work/report/requirements")

shutil.rmtree(mySRS, ignore_errors=True)
shutil.rmtree(myReport,ignore_errors=True)
mySRS.mkdir(exist_ok=True,parents=True)
myReport.mkdir(exist_ok=True,parents=True)

b = RequirementsSet(mySRS)

b.createFakeRequirementsSet()
# Out:
# ([WindowsPath('work/SRS/requirements/ezzmtfx92i5/8h29yexfbixa/48w7q3ecdb506/zzmyjh8z'),
#   WindowsPath('work/SRS/requirements/r9t 3ewuvbl130/k4wlpuzw6 j3bd/pl2d3p0yse'),
#   WindowsPath('work/SRS/requirements/r9t 3ewuvbl130/5ejqyxttr/krxd0ysl'),
#   WindowsPath('work/SRS/requirements/bk6mjxr7x/ww21q6ryf/jbfj75bi6ajgx/np5hnuq7l1lrmh'),
#   WindowsPath('work/SRS/requirements/ul204o1wo/xsltxm563b6bjg/vcjjg3ua1ico'),
#   WindowsPath('work/SRS/requirements/ezzmtfx92i5/x8ba6y5yh4/5f2o6hp71ff'),
#   WindowsPath('work/SRS/requirements/gv6u4ad1odb 43/hnv4 8w7m1kmd/3sfrz2qt4fkl x/lv19g5 jrqkgs'),
#   WindowsPath('work/SRS/requirements/ezzmtfx92i5/8h29yexfbixa/48w7q3ecdb506/b bbx0ur3m3fa'),
#   WindowsPath('work/SRS/requirements/41b4898edeyzgm/f vz 03fm'),
#   WindowsPath('work/SRS/requirements/41b4898edeyzgm/f28zwea/nigrj9e4f'),
#   WindowsPath('work/SRS/requirements/r9t 3ewuvbl130/0emm5c 1apm9'),
#   WindowsPath('work/SRS/requirements/7j s3y52gv/3qbg4nev5s hx/zsct 9iwjj10j5/qdje8fj8v ja'),
#   WindowsPath('work/SRS/requirements/qp31ykjw7vzm/76ae3veurmbi/zc45pzkff8'),
#   WindowsPath('work/SRS/requirements/bk6mjxr7x/mp7he43pvcs9pl/0pchl93m/jqhvh4s4ew'),
#   WindowsPath('work/SRS/requirements/ezzmtfx92i5/sw0zt500/qkv0wczyn8w0/55gn3zsv7'),
#   WindowsPath('work/SRS/requirements/gv6u4ad1odb 43/v2bxsyl7o6/nzqim4y0s7afa/14ai68hxij86'),
#   WindowsPath('work/SRS/requirements/ezzmtfx92i5/8h29yexfbixa/h5tmbjtl8dz20v'),
#   WindowsPath('work/SRS/requirements/q6x87n9z8/5lf6k8 9/zj0zlkpy95r75/m6scjifugz1qyf'),
#   WindowsPath('work/SRS/requirements/bk6mjxr7x/ww21q6ryf/pdxtavij/khek8xcvy'),
#   WindowsPath('work/SRS/requirements/ezzmtfx92i5/sw0zt500/0se8m9chh5m ob/vt2hltbaz'),
#   WindowsPath('work/SRS/requirements/ul204o1wo/0lym dgk/u3xrv4cemy'),
#   WindowsPath('work/SRS/requirements/r9t 3ewuvbl130/5ejqyxttr'),
#   WindowsPath('work/SRS/requirements/1gqsgtt4'),
#   WindowsPath('work/SRS/requirements/7j s3y52gv/3qbg4nev5s hx/cq2oimb1c/7cfplerx29c'),
#   WindowsPath('work/SRS/requirements/7j s3y52gv/m6nlj6 0mfi/5v3c90s4ku/j0s8z6z h2l'),
#   WindowsPath('work/SRS/requirements/gv6u4ad1odb 43/hnv4 8w7m1kmd/r80y86zcd8/josdu4n1 ssb'),
#   WindowsPath('work/SRS/requirements/q6x87n9z8/5lf6k8 9'),
#   WindowsPath('work/SRS/requirements/a8nizemgl/gjpyjy3v/xfbufrp4wt'),
#   WindowsPath('work/SRS/requirements/ezzmtfx92i5/h1bemfdvflk4/1oz 23a 4/ro74j8svn3'),
#   WindowsPath('work/SRS/requirements/7j s3y52gv/wb1n29y68ra/9h92mfwhwzwb9/j5m5k qlhvlx'),
#   WindowsPath('work/SRS/requirements/ezzmtfx92i5/sw0zt500/au2lgpfody/w6eyd80jx'),
#   WindowsPath('work/SRS/requirements/q6x87n9z8/5lf6k8 9/ht1rw4qim2 ch/59j42nbqe4dtd'),
#   WindowsPath('work/SRS/requirements/r9t 3ewuvbl130/vgrl0h10xatix'),
#   WindowsPath('work/SRS/requirements/bk6mjxr7x/ww21q6ryf/k70 iy3q/82u2kzpk6fs'),
#   WindowsPath('work/SRS/requirements/egeu5 uyln2/bs4n9gd wau/ef5l i8gi6 fqc'),
#   WindowsPath('work/SRS/requirements/7j s3y52gv/27wxmw2gd'),
#   WindowsPath('work/SRS/requirements/gv6u4ad1odb 43/v2bxsyl7o6/nzqim4y0s7afa/sf77gosn5f0i'),
#   WindowsPath('work/SRS/requirements/ezzmtfx92i5/wfcbn5vd/6ilfm7s5hm3/enzw0ojm77zi7'),
#   WindowsPath('work/SRS/requirements/ezzmtfx92i5/sw0zt500/0se8m9chh5m ob'),
#   WindowsPath('work/SRS/requirements/egeu5 uyln2/nog4rvcuttjb'),
#   WindowsPath('work/SRS/requirements/3yi17l99/utnv64sw6'),
#   WindowsPath('work/SRS/requirements/gv6u4ad1odb 43/hnv4 8w7m1kmd/r80y86zcd8/b7 reuj8'),
#   WindowsPath('work/SRS/requirements/gv6u4ad1odb 43/v2bxsyl7o6/yz6aepfj6509b'),
#   WindowsPath('work/SRS/requirements/gv6u4ad1odb 43/ewvrkl6t'),
#   WindowsPath('work/SRS/requirements/r9t 3ewuvbl130/5ejqyxttr/7ozvshgo23kp41/yccwcw rpxd'),
#   WindowsPath('work/SRS/requirements/ul204o1wo/xsltxm563b6bjg/aw7m 9x8p zek0/3s4hmtiwnvagw'),
#   WindowsPath('work/SRS/requirements/q6x87n9z8/5lf6k8 9/fx2pk0wk/s3z05aj m'),
#   WindowsPath('work/SRS/requirements/bk6mjxr7x/mp7he43pvcs9pl/3gov f1zt/wy97bhpg84'),
#   WindowsPath('work/SRS/requirements/ul204o1wo/060dd1vwj8k/zaozajk2s0y'),
#   WindowsPath('work/SRS/requirements/ezzmtfx92i5/sw0zt500/mstwyld qri6cm/m6khqjasgc9r'),
#   WindowsPath('work/SRS/requirements/ezzmtfx92i5/h1bemfdvflk4/zmblczot irmc/ewsn4k7ozf9p'),
#   WindowsPath('work/SRS/requirements/bk6mjxr7x/ww21q6ryf/ppe0o27n9zsk'),
#   WindowsPath('work/SRS/requirements/7j s3y52gv/wb1n29y68ra/lac4nahvlm/ezvtn9o71m'),
#   WindowsPath('work/SRS/requirements/41b4898edeyzgm/f28zwea/mhvyancwb8j0j'),
#   WindowsPath('work/SRS/requirements/ezzmtfx92i5/h1bemfdvflk4/wt en82ja/g7mkevtzss4'),
#   WindowsPath('work/SRS/requirements/ul204o1wo/060dd1vwj8k'),
#   WindowsPath('work/SRS/requirements/bk6mjxr7x/ww21q6ryf/k70 iy3q'),
#   WindowsPath('work/SRS/requirements/a8nizemgl/gjpyjy3v/w10y0lo0eu8s'),
#   WindowsPath('work/SRS/requirements/r9t 3ewuvbl130/vgrl0h10xatix/v7bl5zi85n9/4gi y6xnf'),
#   WindowsPath('work/SRS/requirements/f9grq25yk88clo/1ur5hjuj72g/49t6p8rbo11'),
#   WindowsPath('work/SRS/requirements/r9t 3ewuvbl130/ajwaj3593/mjhfjdh9r'),
#   WindowsPath('work/SRS/requirements/gv6u4ad1odb 43/v2bxsyl7o6/nzqim4y0s7afa'),
#   WindowsPath('work/SRS/requirements/q6x87n9z8/dzwshqvpjtf6/rsql1zidpv5ab'),
#   WindowsPath('work/SRS/requirements/gv6u4ad1odb 43/hnv4 8w7m1kmd'),
#   WindowsPath('work/SRS/requirements/ul204o1wo/frp2y6xf9tea/8gfendqu94r78'),
#   WindowsPath('work/SRS/requirements/ezzmtfx92i5/sw0zt500/hhbyj6pr6n'),
#   WindowsPath('work/SRS/requirements/r9t 3ewuvbl130/i9 qx1yi4n6z'),
#   WindowsPath('work/SRS/requirements/bk6mjxr7x/ww21q6ryf/ppe0o27n9zsk/iqu217i2q7f9c8'),
#   WindowsPath('work/SRS/requirements/gv6u4ad1odb 43/4gqtva8bv2'),
#   WindowsPath('work/SRS/requirements/ezzmtfx92i5/wfcbn5vd/0e8w4v5d2ay4'),
#   WindowsPath('work/SRS/requirements/ezzmtfx92i5/h1bemfdvflk4/wt en82ja'),
#   WindowsPath('work/SRS/requirements/ezzmtfx92i5/h1bemfdvflk4/1oz 23a 4/8w66u5x9'),
#   WindowsPath('work/SRS/requirements/gv6u4ad1odb 43/ye0h6h5fvgeni/ wbt1e1xxn/br9fzkrs5'),
#   WindowsPath('work/SRS/requirements/ezzmtfx92i5/wfcbn5vd/6ilfm7s5hm3/ww jegmbjhl'),
#   WindowsPath('work/SRS/requirements/gv6u4ad1odb 43/ye0h6h5fvgeni/2gyrjkodq u8q/96wcze vepn06'),
#   WindowsPath('work/SRS/requirements/gv6u4ad1odb 43/ewvrkl6t/hbqq8paw5ed/zanc0l5y7z'),
#   WindowsPath('work/SRS/requirements/7j s3y52gv/m6nlj6 0mfi'),
#   WindowsPath('work/SRS/requirements/ul204o1wo/xsltxm563b6bjg'),
#   WindowsPath('work/SRS/requirements/bk6mjxr7x/mp7he43pvcs9pl/0pchl93m/6ko ro5w4jr'),
#   WindowsPath('work/SRS/requirements/qp31ykjw7vzm/fhwhuu30'),
#   WindowsPath('work/SRS/requirements/f9grq25yk88clo
yml'),
#   WindowsPath('work/SRS/requirements/gv6u4ad1odb 43/hnv4 8w7m1kmd/scffv6avpd7.yml'),
#   WindowsPath('work/SRS/requirements/f9grq25yk88clo/1ur5hjuj72g/n3cw62je8.yml'),
#   WindowsPath('work/SRS/requirements/3yi17l99/t0dtmv5zyvo/wj72yzzvx .yml'),
#   WindowsPath('work/SRS/requirements/q6x87n9z8/5lf6k8 9/mns284c20/yz6cp8oyexnc.yml'),
#   WindowsPath('work/SRS/requirements/qp31ykjw7vzm/76ae3veurmbi/woo7h42xw5kd8.yml'),
#   WindowsPath('work/SRS/requirements/r9t 3ewuvbl130/ajwaj3593/gsmklr91e/t82i49qm1f.yml'),
#   WindowsPath('work/SRS/requirements/r9t 3ewuvbl130/qdi  jxpa.yml'),
#   WindowsPath('work/SRS/requirements/7j s3y52gv/qqrwix9rbjh.yml'),
#   WindowsPath('work/SRS/requirements/egeu5 uyln2/32 kfvt23b/g0qypnk5kk3.yml'),
#   WindowsPath('work/SRS/requirements/ul204o1wo/0lym dgk/lwyxe47pr5yz.yml'),
#   WindowsPath('work/SRS/requirements/f24iftqmryen.yml'),
#   WindowsPath('work/SRS/requirements/7j s3y52gv/wb1n29y68ra/lac4nahvlm/p3x bbxy.yml'),
#   WindowsPath('work/SRS/requirements/gv6u4ad1odb 43/ 3uc7cfdw09sh/7bqp2hbaor9zrt/orceqsk60.yml'),
#   WindowsPath('work/SRS/requirements/r9t 3ewuvbl130/vgrl0h10xatix/1etolitf/jj74axz1hrtdz7.yml'),
#   WindowsPath('work/SRS/requirements/7j s3y52gv/m6nlj6 0mfi/mprqb2ds5g6c/44m38zu5qyiy.yml'),
#   WindowsPath('work/SRS/requirements/q6x87n9z8/dzwshqvpjtf6/su7orvlqxlz7/n8bz947n2evtj.yml'),
#   WindowsPath('work/SRS/requirements/ezzmtfx92i5/wfcbn5vd/rd cy9xpficd/r 9eumqboe01n.yml'),
#   WindowsPath('work/SRS/requirements/ezzmtfx92i5/sw0zt500/ikyu4 bgxjftpa.yml'),
#   WindowsPath('work/SRS/requirements/q6x87n9z8/zuovp3eo/r47u4lip.yml'),
#   WindowsPath('work/SRS/requirements/egeu5 uyln2/wzl24ahnhzmk.yml'),
#   WindowsPath('work/SRS/requirements/41b4898edeyzgm/xtdltx5kdnda.yml'),
#   WindowsPath('work/SRS/requirements/7j s3y52gv/m6nlj6 0mfi/cctzd854cua9eu/7 slahdj9qn1oe.yml'),
#   WindowsPath('work/SRS/requirements/gv6u4ad1odb 43/yagmp61xhrozfm/bs5nhsrj5zx8u/79nw9gekoha.yml'),
#   WindowsPath('work/SRS/requirements/r9t 3ewuvbl130/mbo  ondvao.yml'),
#   WindowsPath('work/SRS/requirements/r9t 3ewuvbl130/sgcx3oei8ih1/8kj4t1p3.yml'),
#   ...])

# %%
df =b.toPandas()
print(df.head())
type(df["title"][1])
# Out:
#                                                title  \
# 0                                         V4yb6punio
# 1                    Ld4byp63d2xwv3r5eby7kifb1v6o4nl
# 2  Fjy d6rtj3xl0gha2tcx18qjli7ildxcrglk3a5j2rzxtf...
# 3                        Ywpbh8ajkkftec4x1xsf37h1yvv
# 4  Cpco452yp1iubyd7bw7pybpk8z9ckzlljgg8ewdsbset4z...
#
#                                          description  \
# 0  ante Morbi tristique interdum eu lectus ipsum ...
# 1  amet, ipsum nisl, Nullam sit metus laoreet Lor...
# 2  auctor congue libero, iaculis, Curabitur males...
# 3  nec ut justo ligula eu varius nunc dignissim v...
# 4  at aliquam auctor elementum fringilla, Suspend...
#
#                                            rationale validation_status  \
# 0  libero malesuada ultricies, gravida at eleifen...           unvalid
# 1  Nulla sem metus orci risus dui Donec consequat...           unvalid
# 2  Lorem dignissim aliquam congue ex a Etiam rutr...           unvalid
# 3                                       ut dui orci.           unvalid
# 4  sapien finibus placerat amet, interdum laoreet...           unvalid
#
#              fileName
# 0      04uok113ia.yml
# 1     0peedr2e55t.yml
# 2  1 gbuhcrl36pch.yml
# 3     151z3do0s6q.yml
# 4       1x5zo4nhp.yml
# str
